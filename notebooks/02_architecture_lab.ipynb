# %% [markdown]
# # 02 — Architecture Lab
#
# Prototype new layers and attention variants using the building blocks in
# `src/core/`.  This is where you iterate before promoting to `src/`.

# %%
import sys
sys.path.insert(0, '..')

import torch
from src.models.gpt.config import GPTConfig
from src.models.gpt.model import GPT
from src.core.generation import generate
from src.utils.training import count_params

# %%
# ── Build a tiny model for fast iteration ────────────────────────────────
tiny_cfg = GPTConfig(
    vocab_size=50257, block_size=32,
    n_layer=2, n_head=2, n_embd=64,
    dropout=0.0, bias=True,
)
model = GPT(tiny_cfg)
print(f'Parameters: {count_params(model):,}')
# Out:
# Parameters: 3,318,592

# %%
# ── Verify forward pass shapes ────────────────────────────────────────────
B, T = 2, tiny_cfg.block_size
idx = torch.randint(0, tiny_cfg.vocab_size, (B, T))
targets = torch.randint(0, tiny_cfg.vocab_size, (B, T))

logits, loss = model(idx, targets)
print(f'logits: {logits.shape}  |  loss: {loss.item():.4f}')
# Out:
# logits: torch.Size([2, 32, 50257])  |  loss: 10.8149

# %%
# ── Test generation ───────────────────────────────────────────────────────
prompt = torch.randint(0, tiny_cfg.vocab_size, (1, 4))
output = generate(model, prompt, max_new_tokens=10, temperature=1.0, top_k=50)
print(f'Input tokens:  {prompt[0].tolist()}')
print(f'Output tokens: {output[0].tolist()}')
# Out:
# Input tokens:  [32486, 23203, 29402, 2688]
# Output tokens: [32486, 23203, 29402, 2688, 33111, 27585, 49467, 28325, 24324, 14522, 15466, 49451, 47616, 32698]

# %%
# ── Parameter count comparison across model sizes ────────────────────────
configs = {
    'gpt_tiny':   GPTConfig(vocab_size=50257, block_size=16,  n_layer=2,  n_head=2,  n_embd=64),
    'gpt_small':  GPTConfig(vocab_size=50257, block_size=128, n_layer=6,  n_head=6,  n_embd=384),
    'gpt_medium': GPTConfig(vocab_size=50257, block_size=256, n_layer=12, n_head=12, n_embd=768),
}
for name, cfg in configs.items():
    n = count_params(GPT(cfg))
    print(f'{name:12s}: {n:>12,} params  ({n/1e6:.1f}M)')
# Out:
# gpt_tiny    :    3,317,568 params  (3.3M)
# gpt_small   :   29,995,392 params  (30.0M)
# gpt_medium  :  123,849,984 params  (123.8M)
